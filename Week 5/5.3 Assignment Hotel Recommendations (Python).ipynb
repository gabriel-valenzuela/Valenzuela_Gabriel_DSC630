# %%
import numpy as np
import pandas as pd
import random
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import make_pipeline
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn import svm
import warnings
warnings.filterwarnings('ignore')

# %%
filename = 'train.csv'
n = sum(1 for line in open(filename)) - 1
s = 100000
skip = sorted(random.sample(range(1, n+1), n-s))
df = pd.read_csv(filename, skiprows=skip)

# %%
dest = pd.read_csv('destinations.csv')
df.shape
# Out:
# (100000, 24)

# %%
df.to_csv(r'C:\Users\Gabe\Documents\Bellevue University\Predictive Analytics\Week 5\subset_train.csv', index = False)

# %% [markdown]
# ### CSV was exported to perform EDA and Data Preparation in R
#
#
# ### The data prepared CSV will be use for the modeling and algorithms

# %%
df = pd.read_csv('Merged_Prepared_Train.csv')

# %%
df = df.drop(columns='Unnamed: 0')
df.head()
# Out:
#    date_year  date_month  site_name  posa_continent  user_location_country  \
# 0       2014           7         11               3                    205
# 1       2014          11          2               3                     66
# 2       2014           6          2               3                     66
# 3       2013           1          2               3                     66
# 4       2013          10          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   354               25315                       1632
# 1                   462               49272                       2733
# 2                   314               32759                       4171
# 3                   174               46432                       2387
# 4                   149               32073                       5198
#
#    user_id  is_mobile  ...      d140      d141      d142      d143      d144  \
# 0     6450          0  ... -2.302005 -2.314393 -2.131704 -2.278643 -2.246783
# 1    57017          1  ... -2.229237 -2.265149 -2.279183 -2.278814 -2.278939
# 2   102383          0  ... -2.256392 -2.258635 -2.259694 -2.259694 -2.259694
# 3   144246          0  ... -2.336147 -2.297696 -2.286036 -2.342028 -2.340895
# 4   165915          0  ... -2.210931 -2.210931 -2.210931 -2.210931 -2.210931
#
#        d145      d146      d147      d148      d149
# 0 -2.281383 -2.322503 -2.293753 -2.122552 -2.321100
# 1 -2.239722 -2.279183 -2.276290 -2.279183 -2.260095
# 2 -2.257659 -2.259694 -2.259585 -2.259694 -2.022893
# 3 -2.333223 -2.342028 -2.342028 -2.302598 -2.342028
# 4 -2.210931 -2.210931 -2.210931 -2.210931 -2.210931
#
# [5 rows x 176 columns]

# %%
relevant_hotel_info = [df.groupby(['srch_destination_id','hotel_country','hotel_market','hotel_cluster'])['is_booking'].agg(['sum','count'])]
agg = pd.concat(relevant_hotel_info).groupby(level=[0,1,2,3]).sum()
#agg.dropna(inplace=True)
agg.head()
# Out:
#                                                               sum  count
# srch_destination_id hotel_country hotel_market hotel_cluster
# 148                 50            953          42               1      1
# 245                 50            365          25               1      1
# 259                 50            444          15               1      1
# 263                 50            455          16               1      1
# 305                 50            453          77               1      1

# %%
agg['sum_and_cnt'] = 0.85*agg['sum'] + 0.15*agg['count']
agg = agg.groupby(level=[0,1,2]).apply(lambda x: x.astype(float)/x.sum())
agg.reset_index(inplace=True)
agg.head()
# Out:
#    srch_destination_id  hotel_country  hotel_market  hotel_cluster  sum  \
# 0                  148             50           953             42  1.0
# 1                  245             50           365             25  1.0
# 2                  259             50           444             15  1.0
# 3                  263             50           455             16  1.0
# 4                  305             50           453             77  1.0
#
#    count  sum_and_cnt
# 0    1.0          1.0
# 1    1.0          1.0
# 2    1.0          1.0
# 3    1.0          1.0
# 4    1.0          1.0

# %%
agg_pivot = agg.pivot_table(index=['srch_destination_id','hotel_country','hotel_market'], columns='hotel_cluster', values='sum_and_cnt').reset_index()
agg_pivot.head()
# Out:
# hotel_cluster  srch_destination_id  hotel_country  hotel_market   0   1   2  \
# 0                              148             50           953 NaN NaN NaN
# 1                              245             50           365 NaN NaN NaN
# 2                              259             50           444 NaN NaN NaN
# 3                              263             50           455 NaN NaN NaN
# 4                              305             50           453 NaN NaN NaN
#
# hotel_cluster   3   4   5   6  ...  90  91  92  93  94  95  96  97  98  99
# 0             NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 1             NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 2             NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 3             NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
# 4             NaN NaN NaN NaN  ... NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN
#
# [5 rows x 98 columns]

# %%
df = pd.merge(df, agg_pivot, how='left', on=['srch_destination_id','hotel_country','hotel_market'])
df.fillna(0, inplace=True)
df.shape
# Out:
# (542, 271)

# %%
df = df.loc[df['is_booking'] == 1]

# Determing features
X = df.drop(['user_id', 'hotel_cluster', 'is_booking'], axis=1)
y = df.hotel_cluster

# %%
# K-Nearest Neighbor Classifier
from sklearn.neighbors import KNeighborsClassifier
clf = make_pipeline(preprocessing.StandardScaler(), KNeighborsClassifier(n_neighbors=5))
np.mean(cross_val_score(clf, X, y, cv=10, scoring='accuracy'))
# Out:
# 0.611901065651586

# %%
# Random Forest Classifier
clf = make_pipeline(preprocessing.StandardScaler(), RandomForestClassifier(n_estimators=273,max_depth=10,random_state=0))
np.mean(cross_val_score(clf, X, y, cv=10))
# Out:
# 0.5691095486128402

# %%
# Multi-Class Logistic Regression
from sklearn.linear_model import LogisticRegression
clf = make_pipeline(preprocessing.StandardScaler(), LogisticRegression(multi_class='ovr'))
np.mean(cross_val_score(clf, X, y, cv=10))
# Out:
# 0.6501366019042722

# %%
# SVM Classifier
from sklearn import svm
clf = make_pipeline(preprocessing.StandardScaler(), svm.SVC(decision_function_shape='ovo'))
np.mean(cross_val_score(clf, X, y, cv=10))
# Out:
# 0.5875114694032719
